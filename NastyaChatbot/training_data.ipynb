# %% [markdown]
# # Nastya Chatbot Training Data
#
# Takes our large CSV of all the data and converts it to the format of a dataframe with text-response columns.
# The texts are solely from Pratik and the responses are solely from Anastasiia.
#
# References:
#
# - https://towardsdatascience.com/how-to-build-an-easy-quick-and-essentially-useless-chatbot-using-your-own-text-messages-f2cb8b84c11d

# %%
import pandas as pd
from string import punctuation
import re

# %% [markdown]
# ### 1. Getting the data to the format we want it to be in

# %% [markdown]
# Reading in the CSV file

# %%
df = pd.read_csv('data/message_data.csv', index_col=[0])
df.head()
# Out:
#                           content          sender_name   timestamp_ms
# 0                      Okay babes  Anastasiia Morozova  1582067120307
# 1                             !!!         Pratik Karki  1582067116590
# 2                 I just got done         Pratik Karki  1582067113534
# 3        I thought you were done!  Anastasiia Morozova  1582067104121
# 4  The person was a annoying ones         Pratik Karki  1582067101785

# %% [markdown]
# Sorting the dataframe by date

# %%
df.sort_values(by='timestamp_ms', inplace=True)
df.reset_index(inplace=True)
df.head()
# Out:
#     index                                            content  \
# 0  182484                                               Cool
# 1  182483                             That was a quick reply
# 2  182482  Took me a while to realize how cool this fact is.
# 3  182481                                                Lol
# 4  182480                                  That's kinda mean
#
#            sender_name   timestamp_ms
# 0  Anastasiia Morozova  1508118080364
# 1         Pratik Karki  1508386653307
# 2  Anastasiia Morozova  1508417569122
# 3         Pratik Karki  1508421997827
# 4         Pratik Karki  1508422003040

# %% [markdown]
# Adding `is_from_me` column and dropping `index`

# %%
df['is_from_me'] = ['1' if x == 'Pratik Karki' else '0' for x in df['sender_name']]
df.drop('index', axis=1, inplace=True)
df['index'] = df.index
df.head()
# Out:
#                                              content          sender_name  \
# 0                                               Cool  Anastasiia Morozova
# 1                             That was a quick reply         Pratik Karki
# 2  Took me a while to realize how cool this fact is.  Anastasiia Morozova
# 3                                                Lol         Pratik Karki
# 4                                  That's kinda mean         Pratik Karki
#
#     timestamp_ms is_from_me  index
# 0  1508118080364          0      0
# 1  1508386653307          1      1
# 2  1508417569122          0      2
# 3  1508421997827          1      3
# 4  1508422003040          1      4

# %% [markdown]
# ### 2. Now we can make training data
#
# For this, we want to create a dataframe with `text` and `response` columns

# %%
#remove the nulls
df.dropna(subset = ['content'], inplace=True)

#helper functions
def make_sentences(series):
    sentence = '. '.join(series)
    sentence = re.sub(r'http\S+', '', sentence)
    sentence = ''.join(filter(lambda x: ord(x)<128,sentence))
    return sentence

#initiliaze empty df
train_data = pd.DataFrame(columns = ['text','response'])
train_data.at[0, 'text'] = ''

# %% [markdown]
# First we test with a subset of the larger dataframe

# %%
# Create test dataframe to test our function
test_df = pd.DataFrame(df).set_index('index')[5000:5500].copy(deep=True)
test_df
# Out:
#                                                  content          sender_name  \
# index
# 5000                                 See, we go way back  Anastasiia Morozova
# 5001                                   Weâre good bros  Anastasiia Morozova
# 5002                                           Of course         Pratik Karki
# 5003   If he's your bro then that must everyone you'v...         Pratik Karki
# 5004             Wow thanks for taking that away from me  Anastasiia Morozova
# ...                                                  ...                  ...
# 5495   See what matters isnât the intensity or the ...  Anastasiia Morozova
# 5496                           That's what she said haha         Pratik Karki
# 5497                 I'm starting bm at the last episode         Pratik Karki
# 5498                                               Noooo  Anastasiia Morozova
# 5499             Hahaha no there different things matter  Anastasiia Morozova
#
#         timestamp_ms is_from_me
# index
# 5000   1514506389243          0
# 5001   1514506397433          0
# 5002   1514506411094          1
# 5003   1514506440771          1
# 5004   1514506716924          0
# ...              ...        ...
# 5495   1514662718791          0
# 5496   1514664728652          1
# 5497   1514664736566          1
# 5498   1514664981092          0
# 5499   1514665005227          0
#
# [500 rows x 4 columns]

# %%
def create_train_data(train_data, df):
    # store current text and response sentences
    text_sentence = []
    response_sentence = []

    train_data_row = 0

    #iterate through each convo
    for index, row in df.iterrows():
        # retrieve current text and remove end punctuation
        curr_string = row['content'].rstrip(punctuation)

        if row['is_from_me'] == '1':
            # going from response to text
            if len(response_sentence) > 0:
                sentence = make_sentences(response_sentence)
                train_data.at[train_data_row,'response'] = sentence
                response_sentence.clear()
                train_data_row+=1 # only increment when response is over
            text_sentence.append(curr_string)
        else:
            if len(text_sentence) > 0:
                sentence = make_sentences(text_sentence)
                train_data.at[train_data_row,'text'] = sentence
                text_sentence.clear()
            response_sentence.append(curr_string)

    # use this line if last response is Nan
    train_data.iloc[-1, train_data.columns.get_loc('response')] = ''

# %%
create_train_data(train_data, test_df)
train_data
# Out:
#                                                   text  \
# 0
# 1    Of course. If he's your bro then that must eve...
# 2         No I don't want you to take him away from me
# 3                                      Haha. Good luck
# 4                           I said good luck with that
# ..                                                 ...
# 136  I think you should be able to express a full r...
# 137        Yeah you're stronger than me in that aspect
# 138  You don't feel as sad. So you have better ment...
# 139  You just said that you don't let it weigh you ...
# 140  That's what she said haha. I'm starting bm at ...
#
#                                               response
# 0                  See, we go way back. Were good bros
# 1    Wow thanks for taking that away from me. Is it...
# 2    Thats what I meant. And had in mind *evil laug...
# 3                                                 What
# 4                                   Thanks Ill need it
# ..                                                 ...
# 136  Me? No. I feel it a lot, but I know I should h...
# 137                                    How do you mean
# 138  You dont know that. You dont know how or what ...
# 139  See what matters isnt the intensity or the fre...
# 140
#
# [141 rows x 2 columns]

# %% [markdown]
# Then we work with the actual dataset

# %%
create_train_data(train_data, df)
train_data
# Out:
#                                                     text  \
# 0
# 1                                 That was a quick reply
# 2                                 Lol. That's kinda mean
# 3      It's true. I'm mean sometimes. It keeps things...
# 4      Definitely chaotic. I make people question the...
# ...                                                  ...
# 53705   [ ] 1 cups refined flour\n[ ] 4 medium potato...
# 53706  The video chat ended. No hay nada en la seccin...
# 53707  You called Anastasiia.   Anastasiia missed you...
# 53708  To find your phone. Can you ask. If I can use ...
# 53709                                     "across. Funny
#
#                                                 response
# 0                                                   Cool
# 1       Took me a while to realize how cool this fact is
# 2      Didn't intend an insult, but hey, being mean i...
# 3                Are you lawful, neutral or chaotic mean
# 4          Lawful. I'm systematically and elegantly mean
# ...                                                  ...
# 53705                      Anastasiia sent an attachment
# 53706                You missed a call from Anastasiia.
# 53707                                   Why did you call
# 53708  Anastasiia called you. You missed a call from ...
# 53709
#
# [53710 rows x 2 columns]

# %% [markdown]
# Save as CSV

# %%
train_data.to_csv('train_data.csv',index=False)
